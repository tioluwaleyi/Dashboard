# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 12
#       8 import pandas as pd
#      10 fifa = pd.read_csv("input/fifa.csv")
# ---> 12 from learntools.core import binder # type: ignore
#      13 binder.bind(globals())
#      14 from learntools.data_viz_to_coder.ex1 import * # type: ignore
#
# ModuleNotFoundError: No module named 'learntools.core'

# %%
import os
print(os.listdir("input"))  # List files inside the input folder

spotify_filepath = "input/spotify.csv"
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

spotify_data.head()
spotify_data.tail()

plt.figure(figsize=(14,6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

sns.lineplot(data=spotify_data)

list(spotify_data.columns)

sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

plt.xlabel("Date")
# Out:
# ['fifa.csv', 'spotify.csv']
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date', ylabel='Shape of You'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the FIFA dataset
fifa = pd.read_csv("input/fifa.csv")

# Check the first few rows
print(fifa.head())
# Out:
#          Date   ARG  BRA   ESP   FRA  GER  ITA
# 0  1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1  1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 2  1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 3  1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 4  1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
import os
print(os.listdir("input")) 

ign_filepath = "input/ign_scores.csv"



import pandas as pd
ign_data = pd.read_csv(ign_filepath, index_col="Date", parse_dates=True)

print(ign_data)
# Out:
# ['cancer.csv', 'fifa.csv', 'ign_scores.csv', 'spotify.csv']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       4 ign_filepath = "input/ign_scores.csv"
#       8 import pandas as pd
# ----> 9 ign_data = pd.read_csv(ign_filepath, index_col="Date", parse_dates=True)
#      11 print(ign_data)
#
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# List files in the 'input' directory
print(os.listdir("input"))

# Define the file path
ign_filepath = "input/ign_scores.csv"

# Read the CSV with 'Date' as index and parse dates
ign_data =  pd.read_csv(ign_filepath, index_col="Platform")
# Display the DataFrame
print(ign_data)

plt.figure(figsize=(25,10))

plt.title("platforms with the highest average scores")

sns.barplot(x=ign_data.index, y=ign_data['Racing'])

plt.ylabel("Average Score")

plt.figure(figsize=(14,7))

sns.heatmap(data=ign_data, annot=True)

plt.xlabel("Racing")
# Out:
# ['cancer.csv', 'fifa.csv', 'ign_scores.csv', 'spotify.csv']
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# ...

# %%
# The required modules and variables are already imported and defined in previous cells.
# The variable 'df' is already loaded and available.

# Only remove the row and set index if 'TEST-PREP' is a column
if 'TEST-PREP' in df.columns:
	# Remove the row where TEST-PREP is 'Grand total' (case-insensitive)
	df = df[df["TEST-PREP"].str.lower() != "grand total"]
	# Set 'TEST-PREP' as the index
	df.set_index("TEST-PREP", inplace=True)

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tiolu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TEST-PREP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
# ...
